# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/Thomas/ML4QS/Python3Code')

from Chapter4.TemporalAbstraction import NumericalAbstraction

# %%
df = pd.read_csv('data/df_processed.csv')

# %%
AXIS_TRIPLES = {
    "acc_lin": ["acc_lin_x_lowpass", "acc_lin_y_lowpass", "acc_lin_z_lowpass"],
    "acc":     ["acc_x_lowpass", "acc_y_lowpass", "acc_z_lowpass"],
    "gyro":    ["gyro_x_lowpass", "gyro_y_lowpass", "gyro_z_lowpass"],
    "orient":  ["yaw_lowpass", "pitch_lowpass", "roll_lowpass"],
}

def add_axis_combinations(g):
    new_cols = []
    for name, (cx, cy, cz) in AXIS_TRIPLES.items():
        x, y, z = g[cx], g[cy], g[cz]
        g[f"{name}_magnitude"] = np.sqrt(x**2 + y**2 + z**2)
        g[f"{name}_sum"]       = x + y + z
        g[f"{name}_product"]   = x * y * z
        new_cols += [f"{name}_magnitude", f"{name}_sum", f"{name}_product"]
    return g, new_cols

# %%
INDIVIDUAL_COLS = [
    "acc_lin_x_lowpass", "acc_lin_y_lowpass", "acc_lin_z_lowpass",
    "acc_x_lowpass", "acc_y_lowpass", "acc_z_lowpass",
    "gyro_x_lowpass", "gyro_y_lowpass", "gyro_z_lowpass",
    "yaw_lowpass", "pitch_lowpass", "roll_lowpass",
    "hr",
]

AGG_FUNCTIONS = ["mean", "std", "min", "max", "slope"]
WINDOW_SECONDS = 1

def process_set(group):
    g = group.copy().reset_index(drop=True)

    # 1. add the combined axis channels
    g, combined_cols = add_axis_combinations(g)
    feature_cols = INDIVIDUAL_COLS + combined_cols

    # 2. datetime index for time-based rolling
    g.index = pd.to_datetime(g["time"], unit="s")

    # 3. windowed aggregations
    na = NumericalAbstraction()
    for agg in AGG_FUNCTIONS:
        g = na.abstract_numerical(g, feature_cols, WINDOW_SECONDS, agg)

    return g.reset_index(drop=True)

# %%
results = []
for keys, group in df.groupby(['subject','exercise','set_nr','focus'], sort=False):
    print(f"Processing {keys}")
    results.append(process_set(group))

full = pd.concat(results, ignore_index=True)

# drop warm-up NaNs (first row of each set, before rolling window can form)
full = full.dropna().reset_index(drop=True)
print(full.shape)  # → (35976, 175)
# Out:
# Processing (0, 0, 1, 1)
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# Processing (0, 0, 2, 0)
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# Processing (0, 0, 3, 1)
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# ...
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# Processing (0, 1, 3, 1)
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
# /Users/Thomas/ML4QS/Python3Code\Chapter4\TemporalAbstraction.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table[col + '_temp_' + aggregation_function_name + '_ws_' + str(window_size)] = aggregations
